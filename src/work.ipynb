# %% [markdown]
# # **Project 1 : Machine Learning**
#
# ### **Libraries**

# %%
import pandas as pd

# %% [markdown]
# ### **Import data**

# %%
DATA_PATH = "../data/"

test = pd.read_csv(DATA_PATH + "test.csv")
sample_submission = pd.read_csv(DATA_PATH + "sample-submission.csv")
train = pd.read_csv(DATA_PATH + "train.csv")

# %% [markdown]
# ### **Visualization of the data**

# %%
print("Here is test")
display(test.head(10))
print("Here is sample-submission")
display(sample_submission.head(10))
print("Here is train")
display(train.head(10))
# Out:
# Here is test
#        Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  350000          ?      -999.000                       79.589        23.916
# 1  350001          ?       106.398                       67.490        87.949
# 2  350002          ?       117.794                       56.226        96.358
# 3  350003          ?       135.861                       30.604        97.288
# 4  350004          ?        74.159                       82.772        58.731
# 5  350005          ?        95.709                       94.168        66.280
# 6  350006          ?        85.798                       49.059        66.131
# 7  350007          ?       429.273                       75.057       234.610
# 8  350008          ?        70.958                       66.329        60.950
# 9  350009          ?       110.539                        2.820        62.136
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# ...

# %% [markdown]
# ### Data columns

# %%
display(test.columns)
display(train.columns)
display(sample_submission.columns)
# Out:
# Index(['Id', 'Prediction', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')
# Index(['Id', 'Prediction', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
# ...

# %%
import numpy as np
from os import listdir
from os.path import isfile, join

files = [f for f in listdir('../data/') if isfile(join('../data/', f))]
files
# Out:
# ['sample-submission.csv', 'test.csv', 'train.csv']

# %%
, 
                      converters={1: lambda x: 0 if b"b" in x else 1}
# Out:
# (250000,)

# %%
master = np.genfromtxt('../data/train.csv', delimiter=",", skip_header=1, 
                      converters={1: lambda x: float(0) if b"b" in x else float(1)})
train_y, train_tx = master[:,1], np.c_[np.ones(master.shape[0]), np.delete(master, [0,1], axis=1)]

# %%
train_tx.shape
# Out:
# (250000, 31)

# %%
np.delete(master, [0,1], axis=1)
# Out:
# array([[ 138.47 ,   51.655,   97.827, ...,    1.24 ,   -2.475,  113.497],
#        [ 160.937,   68.768,  103.235, ..., -999.   , -999.   ,   46.226],
#        [-999.   ,  162.172,  125.953, ..., -999.   , -999.   ,   44.251],
#        ...,
#        [ 105.457,   60.526,   75.839, ..., -999.   , -999.   ,   41.992],
#        [  94.951,   19.362,   68.812, ..., -999.   , -999.   ,    0.   ],
#        [-999.   ,   72.756,   70.831, ..., -999.   , -999.   ,    0.   ]])

# %%
train_y, train_tx = master[:,1], master.delete([0,1], axis = 1)

# %%
test = np.genfromtxt('../data/test.csv', delimiter=",", skip_header=1)

# %%
np.delete(test, [0,1], axis=1)
# Out:
# (568238, 30)
